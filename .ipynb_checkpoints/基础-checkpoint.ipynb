# %% [markdown]
# # 注释格式

# %%
#单行注释
"""
多行注释
"""
# Out:
# '\n多行注释\n'

# %% [markdown]
# # 变量类型

# %%
'''
姓名：小明
年龄：18 岁
性别：是男生
身高：1.75 米
体重：75.0 公斤
'''
# 在 Python 中，定义变量时是不需要指定变量的类型的
# 在运行的时候，Python 解释器，会根据赋值语句等号右侧的数据
# 自动推导出变量中保存数据的准确类型

# str 表示是一个字符串类型
name = "小明"

# int 表示是一个整数类型
age = 18

# bool 表示是一个布尔类型，真 True 或者假 False
gender = False  # 不是

# float 表示是一个小数类型，浮点数
height = 1.75

weight = 75

print(name)
# Out:
# 小明

# %% [markdown]
# # input

# %%
# 1. 输入苹果的单价
price_str = input("苹果的单价：")

# 2. 输入苹果的重量
weight_str = input("苹果的重量：")

# 3. 计算支付的总金额
# 注意：两个字符串变量之间是不能直接用乘法的
# money = price_str * weight_str

# 1> 将价格转换成小数
price = float(price_str)

# 2> 将重量转换成小数
weight = float(weight_str)

# 3> 用两个小数来计算最终的金额
money = price * weight

print(money)
# Out:
# 苹果的单价：5
# 苹果的重量：5
# 25.0

# %%
price=float(input("苹果的单价："))
weight = float(input("苹果的重量："))
print(price*weight)
# Out:
# 苹果的单价：5
# 苹果的重量：2
# 10.0

# %% [markdown]
# # 格式化输出

# %%
name="Amy"
print("my name is %s"% (name))
# Out:
# my name is Amy

# %%
stu_id=100810
print("my id is %10d"% (stu_id))
# Out:
# my id is     100810

# %%
price = 8.5
weight = 7.5
money = price * weight
print("苹果单价 %10.2f 元／斤，购买了 %10.3f 斤，需要支付 %10.2f 元" % (price, weight, money))
#整数部分代表长度，小数部分代表位数
# Out:
# 苹果单价       8.50 元／斤，购买了      7.500 斤，需要支付      63.75 元

# %%
scale = 0.8
print("the scale of data is %%%d"%(scale*100))
#%% equals %
# Out:
# the scale of data is %80
