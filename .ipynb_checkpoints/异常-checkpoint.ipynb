# %%
try:
    num=int(input("please input a num:"))
    print(num)
except:
    print("please input the right integer ")
# Out:
# please input a num:3.5
# please input the right integer

# %%
try:
    # 提示用户输入一个整数
    num = int(input("输入一个整数："))

    # 使用 8 除以用户输入的整数并且输出
    result = 8 / num

    print(result)
except ValueError:
    print("请输入正确的整数")
except Exception as result:
    print("未知错误 %s" % result)
else:
    print("尝试成功")
finally:
    print("无论是否出现错误都会执行的代码")
# Out:
# 输入一个整数：8
# 1.0
# 尝试成功
# 无论是否出现错误都会执行的代码

# %%
def demo1():
    a= int(input("输入整数："))
    return 8/a

def demo2():
    return demo1()

# 利用异常的传递性，在主程序捕获异常
try:
    print(demo2())
except Exception as result:
    print("未知错误 %s" % result)
# Out:
# 输入整数：8.6
# 未知错误 invalid literal for int() with base 10: '8.6'

# %% [markdown]
# 输入密码

# %%
def password():
    strs=input("Please input your password,no less than 8 characters")
    if len(strs)>=8:
        return strs
    
    #创建异常对象 - 可以使用错误信息字符串作为参数
    e=Exception("Error:the length of password is not available")
    raise e


try:
    print(password())
except Exception as result:
    print(result)
# Out:
# Please input your password,no less than 8 characters123456789
# 123456789
