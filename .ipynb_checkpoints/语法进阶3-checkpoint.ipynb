# %% [markdown]
# # 缺省参数

# %%
gl_list = [6, 3, 9]

# 默认按照升序排序 - 可能会多！

#gl_list.sort()

# 如果需要降序排序，需要执行reverse参数

gl_list.sort(reverse=True)

print(gl_list)
# Out:
# [9, 6, 3]

# %%
def print_info(name, title="", gender=True):
    """

    :param title: 职位
    :param name: 班上同学的姓名
    :param gender: True 男生 False 女生
    """

    gender_text = "男生"

    if not gender:
        gender_text = "女生"

    print("[%s]%s 是 %s" % (title, name, gender_text))


# 假设班上的同学，男生居多！
# 提示：在指定缺省参数的默认值时，应该使用最常见的值作为默认值！
print_info("小明")
print_info("老王")
print_info("小美","班长", gender=False)
# Out:
# []小明 是 男生
# []老王 是 男生
# [班长]小美 是 女生

# %% [markdown]
# # 多值参数

# %%
def demo(num, *nums, **person):

    print(num)
    print(nums)
    print(person)


# demo(1)
demo(1, 2, 3, 4, 5, name="小明", age=18)
# Out:
# 1
# (2, 3, 4, 5)
# {'name': '小明', 'age': 18}

# %%
def sum_numbers(*args):
    result=0;
    
    for each in args:
        result+=each
        
    return result

sum_numbers(1,2,3)
# Out:
# 6
